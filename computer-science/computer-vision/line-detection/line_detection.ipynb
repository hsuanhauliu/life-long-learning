# %% [markdown]
# # Line Detection - Canny Edge Detector

# %%
# %matplotlib notebook

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
ori_img = cv.imread('imgs/test.png')
rgb_img = cv.cvtColor(ori_img, cv.COLOR_BGR2RGB)
gray_img = cv.cvtColor(rgb_img, cv.COLOR_RGB2GRAY)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(rgb_img)
ax2.imshow(gray_img, cmap='gray')
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="846.6666890956743">

# %% [markdown]
# First, we'll apply Canny edge detector without blurring the image.

# %%
canny = cv.Canny(gray_img, 50, 150)
plt.imshow(canny, cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="855.5555782200383">

# %% [markdown]
# As we can see, there's a lot of noise in the image. Now we want to apply Gaussian blurring before applying Canny edge detector.

# %%
blurred_img = cv.GaussianBlur(rgb_img, (13, 13), 0)
gray_img = cv.cvtColor(blurred_img, cv.COLOR_RGB2GRAY)
plt.imshow(blurred_img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
canny = cv.Canny(blur, 50, 150)
plt.imshow(canny, cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="823.8889107144915">
